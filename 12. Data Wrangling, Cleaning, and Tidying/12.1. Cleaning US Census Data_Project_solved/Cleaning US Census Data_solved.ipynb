# %% [markdown]
# # Cleaning US Census Data

# %% [markdown]
# You just got hired as a Data Analyst at the Census Bureau, which collects census data and creates interesting visualizations and insights from it.
#
# The person who had your job before you left you all the data they had for the most recent census. It is in multiple `csv` files. They didn't use pandas, they would just look through these `csv` files manually whenever they wanted to find something. Sometimes they would copy and paste certain numbers into Excel to make charts.
#
# The thought of it makes you shiver. This is not scalable or repeatable.
#
# Your boss wants you to make some scatterplots and histograms by the end of the day. Can you get this data into `pandas` and into reasonable shape so that you can make these histograms?

# %% [markdown]
# ## Inspect the Data!

# %% [markdown]
# 1. The first visualization your boss wants you to make is a scatterplot that shows average income in a state vs proportion of women in that state.
#
#    Open some of the census `csv` files that came with the kit you downloaded. How are they named? What kind of information do they hold? Will they help us make this graph?

# %%
# 10 files named "statesX" (where X are numbers from 0 to 9)

#These files contain the data about the population of each state in the USA,
# incl. race, income and gender

#Yes, these files provide us with the necessary information, but
# it schould be cleaned and reorganized

# %% [markdown]
# 2. It will be easier to inspect this data once we have it in a DataFrame. You can't even call `.head()` on these `csv`s! How are you supposed to read them?
#
#    Using `glob`, loop through the census files available and load them into DataFrames. Then, concatenate all of those DataFrames together into one DataFrame, called something like `us_census`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob

all_files = glob.glob('states*.csv')
states = []
for each_file in all_files:
    data = pd.read_csv(each_file)
    states.append(data)
    
us_census = pd.concat(states)

# %% [markdown]
# 3. Look at the `.columns` and the `.dtypes` of the `us_census` DataFrame. Are those datatypes going to hinder you as you try to make histograms?

# %%
print(us_census.columns)
print(us_census.dtypes)
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'GenderPop'],
#       dtype='object')
# Unnamed: 0     int64
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income        object
# GenderPop     object
# dtype: object

# %% [markdown]
# 4. Look at the `head()` of the DataFrame so that you can understand why some of these `dtypes` are objects instead of integers or floats.
#
#    Start to make a plan for how to convert these columns into the right types for manipulation.

# %%
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0           0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%
# 1           1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%
# 2           2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%
# 3           3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%
# 4           4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%
#
#   Pacific       Income            GenderPop
# 0   0.03%  $43,296.36     2341093M_2489527F
# 1   1.06%  $70,354.74       384160M_349215F
# 2   0.17%  $54,207.82     3299088M_3342840F
# 3   0.15%  $41,935.63     1451913M_1506295F
# 4   0.35%  $67,264.78   19087135M_19334329F

# %% [markdown]
# ## Regex to the Rescue

# %% [markdown]
# 5. Use regex to turn the `Income` column into a format that is ready for conversion into a numerical type.

# %%
us_census['Income'] = us_census.Income.replace('[\$,]', '', regex=True)
us_census['Income'] = pd.to_numeric(us_census['Income'])
# us_census.head()

# %% [markdown]
# 6. Look at the `GenderPop` column. We are going to want to separate this into two columns, the `Men` column, and the `Women` column.
#
#    Split the column into those two new columns using `str.split` and separating out those results.

# %%
GenderPop_data = us_census['GenderPop'].str.split('_')
GenderPop_data.head()
us_census['M_population'] = GenderPop_data.str.get(0)
us_census['F_population'] = GenderPop_data.str.get(1)
us_census = us_census.drop(columns = ['GenderPop'])
us_census.head()
# Out:
#    Unnamed: 0       State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0           0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%
# 1           1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%
# 2           2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%
# 3           3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%
# 4           4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%
#
#   Pacific    Income M_population F_population
# 0   0.03%  43296.36     2341093M     2489527F
# 1   1.06%  70354.74      384160M      349215F
# 2   0.17%  54207.82     3299088M     3342840F
# 3   0.15%  41935.63     1451913M     1506295F
# 4   0.35%  67264.78    19087135M    19334329F

# %% [markdown]
# 7. Convert both of the columns into numerical datatypes.
#
#    There is still an `M` or an `F` character in each entry! We should remove those before we convert.

# %%
us_census['M_population'] = us_census['M_population'].str[:-1]
us_census['M_population'] = pd.to_numeric(us_census['M_population'])
us_census['F_population'] = us_census['F_population'].str[:-1]
us_census['F_population'] = pd.to_numeric(us_census['F_population'])
# us_census['F_population'] = us_census['F_population'].astype('int')
us_census.head()
print(us_census.dtypes)
# Out:
# Unnamed: 0        int64
# State            object
# TotalPop          int64
# Hispanic         object
# White            object
# Black            object
# Native           object
# Asian            object
# Pacific          object
# Income          float64
# M_population      int64
# F_population    float64
# dtype: object

# %%
# something wrong with F_population. let's check
print(us_census.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    60 non-null     int64
#  1   State         60 non-null     object
#  2   TotalPop      60 non-null     int64
#  3   Hispanic      60 non-null     object
#  4   White         60 non-null     object
#  5   Black         60 non-null     object
#  6   Native        60 non-null     object
#  7   Asian         60 non-null     object
#  8   Pacific       55 non-null     object
#  9   Income        60 non-null     float64
#  10  M_population  60 non-null     int64
#  11  F_population  57 non-null     float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 6.1+ KB
# None

# %% [markdown]
# 8. Now you should have the columns you need to make the graph and make sure your boss does not slam a ruler angrily on your desk because you've wasted your whole day cleaning your data with no results to show!
#
#    Use matplotlib to make a scatterplot!

# %%
plt.scatter(us_census.F_population, us_census.Income)
plt.show()

# %% [markdown]
# 9. You want to double check your work. You know from experience that these monstrous csv files probably have `nan` values in them! Print out your column with the number of women per state to see.
#
#    We can fill in those `nan`s by using pandas' `.fillna()` function.
#
#    You have the `TotalPop` per state, and you have the `Men` per state. As an estimate for the `nan` values in the `Women` column, you could use the `TotalPop` of that state minus the `Men` for that state.
#
#    Print out the `Women` column after filling the `nan` values to see if it worked!

# %%
us_census['F_population'] = us_census.F_population.fillna(us_census.TotalPop - us_census.M_population)
us_census['F_population'] = us_census['F_population'].astype('int64')
print(us_census.F_population)
# Out:
# 0     2489527
# 1      349215
# 2     3342840
# 3     1506295
# 4    19334329
# 5     2630239
# 0     2630239
# 1     1841615
# 2      478041
# 3      340810
# 4    10045763
# 5     5123362
# 0     5123362
# 1      696428
# 2      806083
# 3     6556862
# 4     3333382
# 5     1558931
# 0     1558931
# 1     1453125
# 2     2233145
# 3     2364097
# 4      679019
# 5     3057895
# 0     3057895
# 1     3455936
# 2     5038598
# 3     2727005
# 4     1536358
# 5     3081445
# 0     3081445
# 1      504536
# 2      939759
# 3     1390901
# 4      670717
# 5     4561386
# 0     4561386
# 1     1051703
# 2    10131373
# 3     5049925
# 4      353677
# 5     5913084
# 0     5913084
# 1     1942789
# 2     1990780
# 3     6534215
# 4     1869213
# 5      543273
# 0      543273
# 1     2455167
# 2      419713
# 3     3331859
# 4    13367298
# 5     1444150
# 0     1444150
# 1      318031
# 2     4195682
# 3     3497739
# 4      937789
# 5     2890732
# Name: F_population, dtype: int64

# %% [markdown]
# 10. We forgot to check for duplicates! Use `.duplicated()` on your `census` DataFrame to see if we have duplicate rows in there.

# %%
duplicates = us_census.duplicated(subset = us_census.columns[1:])
print(duplicates)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool

# %% [markdown]
# 11. Drop those duplicates using the `.drop_duplicates()` function.

# %%
us_census = us_census.drop_duplicates(subset = us_census.columns[1:])
us_census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 5
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    51 non-null     int64
#  1   State         51 non-null     object
#  2   TotalPop      51 non-null     int64
#  3   Hispanic      51 non-null     object
#  4   White         51 non-null     object
#  5   Black         51 non-null     object
#  6   Native        51 non-null     object
#  7   Asian         51 non-null     object
#  8   Pacific       47 non-null     object
#  9   Income        51 non-null     float64
#  10  M_population  51 non-null     int64
#  11  F_population  51 non-null     int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 5.2+ KB

# %% [markdown]
# 12. Make the scatterplot again. Now, it should be perfect! Your job is secure, for now.

# %%
plt.clf()
plt.scatter(us_census.F_population, us_census.Income)
plt.show()

# %% [markdown]
# ## Histogram of Races

# %% [markdown]
# 13. Now your boss wants you to make a bunch of histograms out of the race data that you have. Look at the `.columns` again to see what the race categories are.

# %%
print(us_census.columns)
print(us_census.columns[3:9])
us_census.head()
# Out:
# Index(['Unnamed: 0', 'State', 'TotalPop', 'Hispanic', 'White', 'Black',
#        'Native', 'Asian', 'Pacific', 'Income', 'M_population', 'F_population'],
#       dtype='object')
# Index(['Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific'], dtype='object')
#    Unnamed: 0       State  TotalPop Hispanic   White   Black  Native   Asian  \
# 0           0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%
# 1           1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%
# 2           2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%
# 3           3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%
# 4           4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%
#
#   Pacific    Income  M_population  F_population
# 0   0.03%  43296.36       2341093       2489527
# 1   1.06%  70354.74        384160        349215
# 2   0.17%  54207.82       3299088       3342840
# 3   0.15%  41935.63       1451913       1506295
# ...

# %% [markdown]
# 14. Try to make a histogram for each one!
#
#     You will have to get the columns into the numerical format, and those percentage signs will have to go.
#
#     Don't forget to fill the `nan` values with something that makes sense! You probably dropped the duplicate rows when making your last graph, but it couldn't hurt to check for duplicates again.

# %%
us_census
# Out:
#    Unnamed: 0                 State  TotalPop Hispanic   White   Black  \
# 0           0               Alabama   4830620    3.75%  61.88%  31.25%
# 1           1                Alaska    733375    5.91%  60.91%   2.85%
# 2           2               Arizona   6641928   29.57%  57.12%   3.85%
# 3           3              Arkansas   2958208    6.22%  71.14%  18.97%
# 4           4            California  38421464   37.29%  40.22%   5.68%
# 5           5              Colorado   5278906   20.78%  69.90%   3.55%
# 1           1           Connecticut   3593222   15.60%  67.68%  10.35%
# 2           2              Delaware    926454    8.82%  64.63%  20.74%
# 3           3  District of Columbia    647484    9.17%  33.10%  51.78%
# 4           4               Florida  19645772   21.34%  59.08%  15.17%
# 5           5               Georgia  10006693    8.42%  54.29%  32.09%
# 1           1                Hawaii   1406299    9.19%  25.03%   2.05%
# ...

# %%
plt.clf()
for column in us_census.columns[3:9]:
    us_census[column] = us_census[column].replace('%', '', regex=True)
    us_census[column] = pd.to_numeric(us_census[column])
    us_census[column] = us_census[column].fillna(100 - us_census['Hispanic'] - us_census['White']\
                                                 - us_census['Black'] - us_census['Native'] - us_census['Asian'])
    us_census[column] = us_census[column]/100
    plt.hist(us_census[column])
    plt.title("Histogram of the Percentage of {column} People per State".format(column=column))
    plt.xlabel("Percentage")
    plt.ylabel("Frequency")
    plt.show()
    plt.clf()
